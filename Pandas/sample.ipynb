# %%
import pandas as pd
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# Key data structures
# 1. Series
# 2. DataFrame

# %%
import pandas as pd

# %%
s = pd.Series([1,2,3,4,5], index=['a','b','c','d','e'])

# %%
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64
