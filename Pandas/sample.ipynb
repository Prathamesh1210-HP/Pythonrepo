# %%
import pandas as pd
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# Key data structures
# 1. Series
# 2. DataFrame

# %%
import pandas as pd

# %%
s = pd.Series([1,2,3,4,5])

# %%
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
