# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# Key data structures
# 1. Series (1 Dimensional)
# 2. DataFrame (2 Dimensional)

# %%
import pandas as pd

# %%
s = pd.Series([1,2,3,4,5], index=['a','b','c','d','e'])

# %%
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
df = pd.DataFrame({"names": ["Patu","Rohan","Harry"], "marks":[100,98,95]})

# %%
df
# Out:
#    names  marks
# 0   Patu    100
# 1  Rohan     98
# 2  Harry     95

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   names   3 non-null      str
#  1   marks   3 non-null      int64
# dtypes: int64(1), str(1)
# memory usage: 180.0 bytes

# %% [markdown]
# Data Selection

# %%
df.iloc[0]
# Out:
# names    Patu
# marks     100
# Name: 0, dtype: object

# %%
df.head()
# Out:
#    names  marks
# 0   Patu    100
# 1  Rohan     98
# 2  Harry     95

# %%
df.rename(columns={"names":"nm"}, inplace=True)
# inplace = True; It modifies your main file, be careful while using it.

# %%
df
# Out:
#       nm  marks
# 0   Patu    100
# 1  Rohan     98
# 2  Harry     95

# %%
df['nm'] = df['nm'].astype(str)

# %%
df
# Out:
#       nm  marks
# 0   Patu    100
# 1  Rohan     98
# 2  Harry     95

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   nm      3 non-null      str
#  1   marks   3 non-null      int64
# dtypes: int64(1), str(1)
# memory usage: 180.0 bytes

# %%
len(df)
# Out:
# 3

# %%
df["Grades"] = [0 for i in range(len(df))]

# %%
df
# Out:
#       nm  marks  Grades
# 0   Patu    100       0
# 1  Rohan     98       0
# 2  Harry     95       0

# %%
def fx(a):
    return a*a
df["Grades + 1"] = df["Grades"].apply(fx)

# %%
df
# Out:
#       nm  marks  Grades  Grades + 1
# 0   Patu    100       0           0
# 1  Rohan     98       0           0
# 2  Harry     95       0           0

# %%
df1 = pd.DataFrame({
    "names": ["Patu","Rutu","Shiv", "Shourya","Samu"],
    "marks": [100,90,94,98,95],
})

# %%
df1
# Out:
#      names  marks
# 0     Patu    100
# 1     Rutu     90
# 2     Shiv     94
# 3  Shourya     98
# 4     Samu     95

# %%
df2 = pd.DataFrame({
    "names": ["Akash","Kim","Kai", "Mu","Sam"],
    "marks": [80,94,90,98,95],
})

# %%
pd.concat([df1, df2])
# Out:
#      names  marks
# 0     Patu    100
# 1     Rutu     90
# 2     Shiv     94
# 3  Shourya     98
# 4     Samu     95
# 0    Akash     80
# 1      Kim     94
# 2      Kai     90
# 3       Mu     98
# 4      Sam     95

# %%
df1 = pd.DataFrame({"name": ["Akash","Rohini"], "marks":[100,80]})

# %%
df2 = pd.DataFrame({"name": ["Akash","Rohini"], "Roll No":[101,102]})

# %%
pd.merge(df1,df2, on="name")
# Out:
#      name  marks  Roll No
# 0   Akash    100      101
# 1  Rohini     80      102
