# %% [markdown]
# Numpy

# %%
import numpy as np

# %%
myarr = np.array([[3,6,32,7]])

# %%
myarr
# Out:
# array([[ 3,  6, 32,  7]])

# %%
myarr[0,2]
# Out:
# 32

# %%
myarr.shape
# Out:
# (1, 4)

# %%
myarr.dtype
# Out:
# dtype('int32')

# %%
myarr[0, 1] = 45

# %%
myarr
# Out:
# array([[ 3, 45, 32,  7]])
